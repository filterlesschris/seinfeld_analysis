# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Read in the CSV files
merged_df = pd.read_csv('../rawData/merged_scripts.csv')
episode_df = pd.read_csv('../rawData/episode_info.csv')

# Drop the "Unnamed: 0" and "Unnamed: 0.1" columns
merged_df = merged_df.drop("Unnamed: 0", 1)
episode_df = episode_df.drop("Unnamed: 0", 1)

# Drop S01E00, since we don't have any sentiment for that
episode_df = episode_df[1:episode_df.shape[0]]

# %%
merged_df.tail()
# Out:
#        SEID  EpisodeNo  Season  SentimentTotal  LineCountTotal  \
# 168  S09E17         17       9        0.050767             301
# 169  S09E18         18       9        0.085210             299
# 170  S09E19         19       9        0.056641             364
# 171  S09E20         20       9        0.072543             316
# 172  S09E23         23       9        0.035249             713
#
#      WordCountTotal  SentimentJerry  LineCountJerry  WordCountJerry  \
# 168            3074       -0.052106              76             678
# 169            2697        0.111630              72             579
# 170            2740        0.064530             105             619
# 171            2784        0.011879              75             585
# 172            6986        0.071567             151            1334
#
#      SentimentGeorge       ...        WordCountElaine  SentimentMainChars  \
# 168         0.025762       ...                  412.0            0.059635
# ...

# %%
episode_df.head()
# Out:
#    Season  EpisodeNo              Title    AirDate  \
# 1       1          1       The Stakeout  31-May-90
# 2       1          2        The Robbery   7-Jun-90
# 3       1          3     Male Unbonding  14-Jun-90
# 4       1          4      The Stock Tip  21-Jun-90
# 5       2          1  The Ex-Girlfriend  16-Jan-91
#
#                        Writers      Director    SEID  IMDB Rating
# 1  Larry David, Jerry Seinfeld  Tom Cherones  S01E01          7.8
# 2                 Matt Goldman  Tom Cherones  S01E02          7.7
# 3  Larry David, Jerry Seinfeld  Tom Cherones  S01E03          7.5
# 4  Larry David, Jerry Seinfeld  Tom Cherones  S01E04          7.7
# 5  Larry David, Jerry Seinfeld  Tom Cherones  S02E01          7.8

# %%
### Merge both data frames on SEID
seinfeld_df = pd.merge(episode_df, merged_df, on = "SEID", how = "left")
seinfeld_df.head()
# Out:
#    Season_x  EpisodeNo_x              Title    AirDate  \
# 0         1            1       The Stakeout  31-May-90
# 1         1            2        The Robbery   7-Jun-90
# 2         1            3     Male Unbonding  14-Jun-90
# 3         1            4      The Stock Tip  21-Jun-90
# 4         2            1  The Ex-Girlfriend  16-Jan-91
#
#                        Writers      Director    SEID  IMDB Rating  \
# 0  Larry David, Jerry Seinfeld  Tom Cherones  S01E01          7.8
# 1                 Matt Goldman  Tom Cherones  S01E02          7.7
# 2  Larry David, Jerry Seinfeld  Tom Cherones  S01E03          7.5
# 3  Larry David, Jerry Seinfeld  Tom Cherones  S01E04          7.7
# 4  Larry David, Jerry Seinfeld  Tom Cherones  S02E01          7.8
#
#    EpisodeNo_y  Season_y       ...        WordCountElaine  SentimentMainChars  \
# 0            1         1       ...                  381.0            0.190497
# ...

# %%
# Drop EpisodeNo_y and Season_y
seinfeld_df = seinfeld_df.drop("EpisodeNo_y", 1)
seinfeld_df = seinfeld_df.drop("Season_y", 1)

# Rename EpsodeNo_x and Season_x
seinfeld_df = seinfeld_df.rename(index=str, columns = {"EpisodeNo_x": "EpisodeNo", "Season_x": "Season"})
seinfeld_df.head()
# Out:
#    Season  EpisodeNo              Title    AirDate  \
# 0       1          1       The Stakeout  31-May-90
# 1       1          2        The Robbery   7-Jun-90
# 2       1          3     Male Unbonding  14-Jun-90
# 3       1          4      The Stock Tip  21-Jun-90
# 4       2          1  The Ex-Girlfriend  16-Jan-91
#
#                        Writers      Director    SEID  IMDB Rating  \
# 0  Larry David, Jerry Seinfeld  Tom Cherones  S01E01          7.8
# 1                 Matt Goldman  Tom Cherones  S01E02          7.7
# 2  Larry David, Jerry Seinfeld  Tom Cherones  S01E03          7.5
# 3  Larry David, Jerry Seinfeld  Tom Cherones  S01E04          7.7
# 4  Larry David, Jerry Seinfeld  Tom Cherones  S02E01          7.8
#
#    SentimentTotal  LineCountTotal       ...        WordCountElaine  \
# 0        0.173524             557       ...                  381.0
# 1       -0.002193             280       ...                  570.0
# ...

# %%
# Export to CSV
seinfeld_df.to_csv('../rawData/seinfeld.csv')

# %%
##### Not doing anything with it yet, but something to consider is how to handle the two-part episodes...

# %%
# There are 3 two-part episodes... we're going to divide those into two separate episodes for the purpose of our data
# Two-part episodes are:
# 1) S01E01
# 2) S05E18
# 3) S09E23

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
s0101 = seinfeld_df.loc[seinfeld_df["SEID"] == "S01E01",:]

#Halve the LineCount and WordCount variables
s0101["LineCountTotal"] = s0101["LineCountTotal"] / 2
s0101["WordCountTotal"] = s0101["WordCountTotal"] / 2

s0101["LineCountJerry"] = s0101["LineCountJerry"] / 2
s0101["WordCountJerry"] = s0101["WordCountJerry"] / 2

s0101["LineCountGeorge"] = s0101["LineCountGeorge"] / 2
s0101["WordCountGeorge"] = s0101["WordCountGeorge"] / 2

s0101["LineCountKramer"] = s0101["LineCountKramer"] / 2
s0101["WordCountKramer"] = s0101["WordCountKramer"] / 2

s0101["LineCountElaine"] = s0101["LineCountElaine"] / 2
s0101["WordCountElaine"] = s0101["WordCountElaine"] / 2

s0101["LineCountMainChars"] = s0101["LineCountMainChars"] / 2
s0101["WordCountMainChars"] = s0101["WordCountMainChars"] / 2

s0101["LineCountSecondary"] = s0101["LineCountSecondary"] / 2
s0101["WordCountSecondary"] = s0101["WordCountSecondary"] / 2

s0101["LineCountOther"] = s0101["LineCountOther"] / 2
s0101["WordCountOther"] = s0101["WordCountOther"] / 2

# %%
s0101
# Out:
#    Season  EpisodeNo         Title    AirDate                      Writers  \
# 0       1          1  The Stakeout  31-May-90  Larry David, Jerry Seinfeld
#
#        Director    SEID  IMDB Rating  SentimentTotal  LineCountTotal  \
# 0  Tom Cherones  S01E01          7.8        0.173524           278.5
#
#         ...        WordCountElaine  SentimentMainChars  LineCountMainChars  \
# 0       ...                  190.5            0.190497               204.0
#
#    WordCountMainChars  SentimentSecondary  LineCountSecondary  \
# 0              2652.0             0.11882                29.5
#
#    WordCountSecondary  SentimentOther  LineCountOther  WordCountOther
# 0               224.5        0.094559            45.0           414.5
#
# [1 rows x 32 columns]

# %%
s518 = seinfeld_df.loc[seinfeld_df["SEID"] == "S05E18",:]

#Halve the LineCount and WordCount variables
s518["LineCountTotal"] = s518["LineCountTotal"] / 2
s518["WordCountTotal"] = s518["WordCountTotal"] / 2

s518["LineCountJerry"] = s518["LineCountJerry"] / 2
s518["WordCountJerry"] = s518["WordCountJerry"] / 2

s518["LineCountGeorge"] = s518["LineCountGeorge"] / 2
s518["WordCountGeorge"] = s518["WordCountGeorge"] / 2

s518["LineCountKramer"] = s518["LineCountKramer"] / 2
s518["WordCountKramer"] = s518["WordCountKramer"] / 2

s518["LineCountElaine"] = s518["LineCountElaine"] / 2
s518["WordCountElaine"] = s518["WordCountElaine"] / 2

s518["LineCountMainChars"] = s518["LineCountMainChars"] / 2
s518["WordCountMainChars"] = s518["WordCountMainChars"] / 2

s518["LineCountSecondary"] = s518["LineCountSecondary"] / 2
s518["WordCountSecondary"] = s518["WordCountSecondary"] / 2

s518["LineCountOther"] = s518["LineCountOther"] / 2
s518["WordCountOther"] = s518["WordCountOther"] / 2

# %%
s518
# Out:
#     Season  EpisodeNo          Title        AirDate  \
# 80       5         18  The Raincoats  April 28 1994
#
#                                               Writers      Director    SEID  \
# 80  Tom Gammill, Max Pross and Larry David, Jerry ...  Tom Cherones  S05E18
#
#     IMDB Rating  SentimentTotal  LineCountTotal       ...        \
# 80          8.6        0.108771           365.0       ...
#
#     WordCountElaine  SentimentMainChars  LineCountMainChars  \
# 80            206.0            0.128911               182.5
#
#     WordCountMainChars  SentimentSecondary  LineCountSecondary  \
# 80              1631.5            0.091456               123.5
#
#     WordCountSecondary  SentimentOther  LineCountOther  WordCountOther
# 80              1078.0        0.086042            59.0           624.5
#
# [1 rows x 32 columns]

# %%
s0923 = seinfeld_df.loc[seinfeld_df["SEID"] == "S09E23",:]

# Halve the LineCount and WordCount variables
s0923["LineCountTotal"] = s0923["LineCountTotal"] / 2
s0923["WordCountTotal"] = s0923["WordCountTotal"] / 2

s0923["LineCountJerry"] = s0923["LineCountJerry"] / 2
s0923["WordCountJerry"] = s0923["WordCountJerry"] / 2

s0923["LineCountGeorge"] = s0923["LineCountGeorge"] / 2
s0923["WordCountGeorge"] = s0923["WordCountGeorge"] / 2

s0923["LineCountKramer"] = s0923["LineCountKramer"] / 2
s0923["WordCountKramer"] = s0923["WordCountKramer"] / 2

s0923["LineCountElaine"] = s0923["LineCountElaine"] / 2
s0923["WordCountElaine"] = s0923["WordCountElaine"] / 2

s0923["LineCountMainChars"] = s0923["LineCountMainChars"] / 2
s0923["WordCountMainChars"] = s0923["WordCountMainChars"] / 2

s0923["LineCountSecondary"] = s0923["LineCountSecondary"] / 2
s0923["WordCountSecondary"] = s0923["WordCountSecondary"] / 2

s0923["LineCountOther"] = s0923["LineCountOther"] / 2
s0923["WordCountOther"] = s0923["WordCountOther"] / 2

# Create a new row for each half of episode
s09231 = s0923
s09231["EpisodeNo"] = 23.1
s09231["SEID"] = "S09E23.1"

s09232 = s0923
s09232["EpisodeNo"] = 23.1
s09232["SEID"] = "S09E23.1"
